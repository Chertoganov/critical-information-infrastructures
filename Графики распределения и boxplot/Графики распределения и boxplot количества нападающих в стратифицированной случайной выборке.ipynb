# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# заружаем стратифицированный случайный чистый набор данных инцидентов на объекты инфраструктуры с использованием типа оружия - рукопашный бой (не огнестрельное оружие)
df1 = pd.read_csv('кол_во_атакующих_стратифицированная_случайная_выборка_18_инцидентов_рукопашный_бой.csv')

# %%
# загружаем стратифицированный случайный чистый набор данных инцидентов на объекты инфраструктуры с использованием типа оружия - оборудование для саботажа
df2 = pd.read_csv('кол_во_атакующих_стратифицированная_случайная_выборка_18_инцидентов_саботаж.csv')

# %%
# создаем копии датафреймов
df11 = df1
df22 = df2

# %%
# делаем подписи для графиков
df11["распределение количества нападающих с использованием рукопашного боя"] = df1["nperps"]
df22["распределение количества нападающих с использованием оборудования для саботажа"] = df2["nperps"]

# %%
# делаем подписи для графиков
df11["Boxplot - рукопашный бой"] = df1["nperps"]
df22["Boxplot - саботаж"] = df2["nperps"]

# %%
# Boxplot - смотрим средние значения количества нападающих на стратифицированный случайный чистый набор данных инцидентов на объекты инфраструктуры с использованием типа оружия - рукопашный бой (не огнестрельное оружие)
import seaborn as sns
tips = sns.load_dataset("tips")
ax = sns.boxplot(x=df1["Boxplot - рукопашный бой"], color = 'grey')

# %%
# Boxplot - смотрим средние значения количества нападающих на стратифицированный случайный чистый набор данных инцидентов на объекты инфраструктуры с использованием типа оружия - оборудование для саботажа
import seaborn as sns
ax = sns.boxplot(x=df2["Boxplot - саботаж"], color = 'grey')

# %%
sns.histplot(data=df11, x="распределение количества нападающих с использованием рукопашного боя", color = 'grey', kde=True)
# Out:
# <AxesSubplot:xlabel='распределение количества нападающих с использованием рукопашного боя', ylabel='Count'>

# %%
sns.histplot(data=df22, x="распределение количества нападающих с использованием оборудования для саботажа", color = 'grey', kde=True)
# Out:
# <AxesSubplot:xlabel='распределение количества нападающих с использованием оборудования для саботажа', ylabel='Count'>
