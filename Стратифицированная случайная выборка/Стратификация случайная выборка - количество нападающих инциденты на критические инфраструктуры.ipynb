# %% [markdown]
# # Пример как работает стратифицированная случайная выборка

# %%
import pandas as pd

#create DataFrame
df = pd.DataFrame({'team': ['A', 'A', 'B', 'B', 'B', 'B', 'B', 'B'],
                   'position': ['G', 'G', 'F', 'G', 'F', 'F', 'C', 'C'],
                   'assists': [5, 7, 7, 8, 5, 7, 6, 9],
                   'rebounds': [11, 8, 10, 6, 6, 9, 6, 10]})

#view DataFrame
df
# Out:
#   team position  assists  rebounds
# 0    A        G        5        11
# 1    A        G        7         8
# 2    B        F        7        10
# 3    B        G        8         6
# 4    B        F        5         6
# 5    B        F        7         9
# 6    B        C        6         6
# 7    B        C        9        10

# %%
import numpy as np

#define total sample size desired
N = 4

#perform stratified random sampling
df.groupby('team', group_keys=False).apply(lambda x: x.sample(int(np.rint(N*len(x)/len(df))))).sample(frac=1).reset_index(drop=True)
# Out:
#   team position  assists  rebounds
# 0    B        C        6         6
# 1    A        G        7         8
# 2    B        F        7         9
# 3    B        G        8         6

# %% [markdown]
# # Мои данные

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# загружаем чистый набор данных инцдентов на критические инфраструктуры с использованием рукопашного боя (32 инцидента)
df1 = pd.read_csv('Facility_Melee_clean_32_dataset.csv')
df1.head()
# Out:
#         eventid  iyear  imonth  iday  approxdate  extended resolution  \
# 0  198106230008   1981       6    23         NaN         0        NaN
# 1  198201220005   1982       1    22         NaN         0        NaN
# 2  198203260011   1982       3    26         NaN         0        NaN
# 3  199107120014   1991       7    12         NaN         0        NaN
# 4  199203210008   1992       3    21         NaN         0        NaN
#
#    country         country_txt  region  ... addnotes scite1 scite2  scite3  \
# 0      362  West Germany (FRG)       8  ...      NaN    NaN    NaN     NaN
# 1      159                Peru       3  ...      NaN    NaN    NaN     NaN
# 2      159                Peru       3  ...      NaN    NaN    NaN     NaN
# 3      142         Netherlands       8  ...      NaN    NaN    NaN     NaN
# 4       15             Austria       8  ...      NaN    NaN    NaN     NaN
#
#    dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
# создаем класс по которому будет происходить разделение
df1["fight"] = "рукопашный бой"

# %%
# смотрим класс по которому будет происходить разделение
df1["fight"]
# Out:
# 0     рукопашный бой
# 1     рукопашный бой
# 2     рукопашный бой
# 3     рукопашный бой
# 4     рукопашный бой
# 5     рукопашный бой
# 6     рукопашный бой
# 7     рукопашный бой
# 8     рукопашный бой
# 9     рукопашный бой
# 10    рукопашный бой
# 11    рукопашный бой
# 12    рукопашный бой
# 13    рукопашный бой
# 14    рукопашный бой
# 15    рукопашный бой
# 16    рукопашный бой
# 17    рукопашный бой
# 18    рукопашный бой
# 19    рукопашный бой
# 20    рукопашный бой
# 21    рукопашный бой
# 22    рукопашный бой
# 23    рукопашный бой
# 24    рукопашный бой
# 25    рукопашный бой
# 26    рукопашный бой
# 27    рукопашный бой
# 28    рукопашный бой
# 29    рукопашный бой
# 30    рукопашный бой
# 31    рукопашный бой
# Name: fight, dtype: object

# %%
# размер чистыого набора данных инцидентов на критические инфраструктуры с использованием рукопашного боя (32 инцидента)
df1.shape
# Out:
# (32, 136)

# %%
# загружаем чистый набор данных инцдентов на критические инфраструктуры с использованием оборудования для саботажа (20 инцидентов)
df2 = pd.read_csv('Facility_Sabotage_Equipment_clean_20_dataset.csv')
df2.head()
# Out:
#         eventid  iyear  imonth  iday             approxdate  extended  \
# 0  197005290005   1970       5    29  May 27 - June 5, 1970         0
# 1  198106050007   1981       6     5                    NaN         0
# 2  198710050012   1987      10     5                    NaN         0
# 3  198711070018   1987      11     7                    NaN         0
# 4  198809250009   1988       9    25                    NaN         0
#
#    resolution  country    country_txt  region  ...  \
# 0         NaN      217  United States       1  ...
# 1         NaN       83      Guatemala       2  ...
# 2         NaN      217  United States       1  ...
# 3         NaN      217  United States       1  ...
# 4         NaN      217  United States       1  ...
#
#                                             addnotes  \
# 0  The USS Richard B. Anderson departed from San ...
# 1                                                NaN
# 2  Although the lift was closed for winter openin...
# ...

# %%
# создаем класс по которому будет происходить разделение
df2["fight"] = "саботаж"

# %%
# смотрим класс по которому будет происходить разделение
df2["fight"]
# Out:
# 0     саботаж
# 1     саботаж
# 2     саботаж
# 3     саботаж
# 4     саботаж
# 5     саботаж
# 6     саботаж
# 7     саботаж
# 8     саботаж
# 9     саботаж
# 10    саботаж
# 11    саботаж
# 12    саботаж
# 13    саботаж
# 14    саботаж
# 15    саботаж
# 16    саботаж
# 17    саботаж
# 18    саботаж
# 19    саботаж
# Name: fight, dtype: object

# %%
# размер чистыого набора данных инцидентов на критические инфраструктуры с использованием оборудования для саботажа (20 инцидентов)
df2.shape
# Out:
# (20, 136)

# %%
import numpy as np

# определяем размер выборки для первой группы (рукопашный бой)
N = 18

# делаем стратифицированную случайную выборку
a = df1.groupby('fight', group_keys=False).apply(lambda x: x.sample(int(np.rint(N*len(x)/len(df1))))).sample(frac=1).reset_index(drop=True)
a
# Out:
#          eventid  iyear  imonth  iday  approxdate  extended resolution  \
# 0   200612310008   2006      12    31         NaN         0        NaN
# 1   201705240049   2017       5    24         NaN         0        NaN
# 2   201511110065   2015      11    11         NaN         0        NaN
# 3   199107120014   1991       7    12         NaN         0        NaN
# 4   201808260015   2018       8    25         NaN         0        NaN
# 5   199209210013   1992       9    21         NaN         0        NaN
# 6   199203260006   1992       3    26         NaN         0        NaN
# 7   199410180008   1994      10    18         NaN         0        NaN
# 8   199503180010   1995       3    18         NaN         0        NaN
# 9   201606230050   2016       6    23         NaN         0        NaN
# 10  198106230008   1981       6    23         NaN         0        NaN
# 11  201409250028   2014       9    25         NaN         0        NaN
# ...

# %%
# смотрим стратифицированную случайную выборку
a.nperps
# Out:
# 0      5.0
# 1     20.0
# 2      3.0
# 3     70.0
# 4      4.0
# 5     60.0
# 6     28.0
# 7     12.0
# 8      1.0
# 9     15.0
# 10    30.0
# 11     3.0
# 12    14.0
# 13     8.0
# 14    40.0
# 15    20.0
# 16    30.0
# 17     1.0
# Name: nperps, dtype: float64

# %%
import numpy as np

# определяем размер выборки для второй группы (саботаж)
N = 18

# делаем стратифицированную случайную выборку
b = df2.groupby('fight', group_keys=False).apply(lambda x: x.sample(int(np.rint(N*len(x)/len(df2))))).sample(frac=1).reset_index(drop=True)
b
# Out:
#          eventid  iyear  imonth  iday             approxdate  extended  \
# 0   198810250013   1988      10    25    October 25-26, 1988         0
# 1   201707280045   2017       7    28                    NaN         0
# 2   201810070039   2018      10     7                    NaN         0
# 3   198711070018   1987      11     7                    NaN         0
# 4   198905300021   1989       5    30                    NaN         0
# 5   201103010026   2011       3     1                    NaN         0
# 6   201103010025   2011       3     1                    NaN         0
# 7   201310070055   2013      10     7                    NaN         0
# 8   198106050007   1981       6     5                    NaN         0
# 9   200005080002   2000       5     8                    NaN         0
# 10  197005290005   1970       5    29  May 27 - June 5, 1970         0
# 11  201009050031   2010       9     5                    NaN         0
# ...

# %%
# смотрим стратифицированную случайную выборку
b.nperps
# Out:
# 0       4.0
# 1       1.0
# 2       1.0
# 3       4.0
# 4       2.0
# 5     100.0
# 6     100.0
# 7       1.0
# 8       3.0
# 9      80.0
# 10      1.0
# 11     10.0
# 12    100.0
# 13     30.0
# 14      4.0
# 15      1.0
# 16     25.0
# 17      1.0
# Name: nperps, dtype: float64

# %%
a["fight"]
# Out:
# 0     рукопашный бой
# 1     рукопашный бой
# 2     рукопашный бой
# 3     рукопашный бой
# 4     рукопашный бой
# 5     рукопашный бой
# 6     рукопашный бой
# 7     рукопашный бой
# 8     рукопашный бой
# 9     рукопашный бой
# 10    рукопашный бой
# 11    рукопашный бой
# 12    рукопашный бой
# 13    рукопашный бой
# 14    рукопашный бой
# 15    рукопашный бой
# 16    рукопашный бой
# 17    рукопашный бой
# Name: fight, dtype: object

# %%
a
# Out:
#          eventid  iyear  imonth  iday  approxdate  extended resolution  \
# 0   200612310008   2006      12    31         NaN         0        NaN
# 1   201705240049   2017       5    24         NaN         0        NaN
# 2   201511110065   2015      11    11         NaN         0        NaN
# 3   199107120014   1991       7    12         NaN         0        NaN
# 4   201808260015   2018       8    25         NaN         0        NaN
# 5   199209210013   1992       9    21         NaN         0        NaN
# 6   199203260006   1992       3    26         NaN         0        NaN
# 7   199410180008   1994      10    18         NaN         0        NaN
# 8   199503180010   1995       3    18         NaN         0        NaN
# 9   201606230050   2016       6    23         NaN         0        NaN
# 10  198106230008   1981       6    23         NaN         0        NaN
# 11  201409250028   2014       9    25         NaN         0        NaN
# ...

# %%
b["fight"]
# Out:
# 0     саботаж
# 1     саботаж
# 2     саботаж
# 3     саботаж
# 4     саботаж
# 5     саботаж
# 6     саботаж
# 7     саботаж
# 8     саботаж
# 9     саботаж
# 10    саботаж
# 11    саботаж
# 12    саботаж
# 13    саботаж
# 14    саботаж
# 15    саботаж
# 16    саботаж
# 17    саботаж
# Name: fight, dtype: object

# %%
b
# Out:
#          eventid  iyear  imonth  iday             approxdate  extended  \
# 0   198810250013   1988      10    25    October 25-26, 1988         0
# 1   201707280045   2017       7    28                    NaN         0
# 2   201810070039   2018      10     7                    NaN         0
# 3   198711070018   1987      11     7                    NaN         0
# 4   198905300021   1989       5    30                    NaN         0
# 5   201103010026   2011       3     1                    NaN         0
# 6   201103010025   2011       3     1                    NaN         0
# 7   201310070055   2013      10     7                    NaN         0
# 8   198106050007   1981       6     5                    NaN         0
# 9   200005080002   2000       5     8                    NaN         0
# 10  197005290005   1970       5    29  May 27 - June 5, 1970         0
# 11  201009050031   2010       9     5                    NaN         0
# ...

# %%
a.shape
# Out:
# (18, 136)

# %%
b.shape
# Out:
# (18, 136)

# %%
a.to_csv("кол_во_атакующих_стратифицированная_случайная_выборка_18_инцидентов_рукопашный_бой.csv", index = False)
b.to_csv("кол_во_атакующих_стратифицированная_случайная_выборка_18_инцидентов_саботаж.csv", index = False)
